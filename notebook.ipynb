# %%
import os
from dotenv import load_dotenv

load_dotenv("../.env")  # nga brenda chat3_macro_position/
key = os.getenv("FRED_API_KEY")
print(repr(key))
print(len(key) if key else "None")
# Out:
# 'your_key_here'
# 13
